# %%
while True:
    idade = int(input("Digite sua idade: "))
    valor_total = float(input("Digite o valor total na carteira: R$"))

    if idade < 16:
        print("Entrada permitida apenas com acompanhante!")
    else:
        if valor_total >= 30:
            print("Ingresso comprado! Bom filme")
        else:
            print("Saldo insuficiente para o ingresso!")
            
    continuar = input("Deseja verificar outro cliente? (s/n)").lower()
    
    if continuar == 'n':
        print("Encerrando o sistema!")
        break
# Out:
# Digite sua idade:  10
# Digite o valor total na carteira: R$ 200
# Entrada permitida apenas com acompanhante!
# Deseja verificar outro cliente? (s/n) s
# Digite sua idade:  20
# Digite o valor total na carteira: R$ 10
# Saldo insuficiente para o ingresso!
# Deseja verificar outro cliente? (s/n) s
# Digite sua idade:  40
# Digite o valor total na carteira: R$ 500
# Ingresso comprado! Bom filme
# Deseja verificar outro cliente? (s/n) n
# Encerrando o sistema!
